# %%
# Author: Arthur Prigent
# Email: arthur.prigent@univ-brest.fr

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import glob
import datetime as dt
import gsw
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
import ArcTools as Atools

import matplotlib.path as mpath
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import ArcTools as Atools

# %%
# read
dir_clim = '/data0/user/aprigent/ISAS/ISAS17_Mask.nc'
mask = xr.open_dataset(dir_clim)
zi = mask.depthCFD.data

# %% [markdown]
# # Vertical interpolation function

# %%
def interp_prof(x_old, y_old, x_new):

    # Import interpolation methods from SciPy
    # (only Akima1DInterpolator is actually used below)
    from scipy.interpolate import Akima1DInterpolator
    
    yi = []   # list to store interpolated profiles
    iyi = []  # list to store indices of successfully interpolated profiles
    
    # Loop over each profile (rows of y_old)
    for i in range(0, y_old.shape[0]):
        
        # Extract the i-th profile
        y = y_old[i, :]
        x = x_old[i, :]
        
        # Identify non-NaN values in y and x_old
        inans_y = ~np.isnan(y)
        inans_x = ~np.isnan(x)
        
        # Keep only points where both x and y are valid
        inans = inans_y * inans_x
        
        # Proceed only if there are any valid points
        if np.any(inans):
            
            # Need at least two valid points for interpolation
            if len(y[inans]) > 1:

                # Create Akima spline interpolator using valid data points
                spl = Akima1DInterpolator(x[inans], y[inans])
                
                # Interpolate profile onto the new x grid
                prof = spl(x_new)
                
                # Store interpolated profile and its original index
                yi.append(prof)
                iyi.append(i)
                
    # Return:
    # - array of interpolated profiles
    # - array of indices of profiles that were successfully interpolated
    return np.array(yi), np.array(iyi)

# %%
## NOT USED ##

def extrap_prof(param):
    """ Extrapolates the first valid value upward
    """
    
    # Loop over each profile (assumes param is 2D: profiles x depth)
    for j in range(0, len(param)): 
        
        # Extract the j-th profile
        prof = param[j, :]
        
        # Start from the first depth level
        i = 0
        x = prof[i]
        
        # Move downward in the profile while:
        #  - the current value is NaN
        #  - OR we are still within the first 4 indices (i <= 3)
        while np.isnan(x) | i <= 3:
            x = prof[i]   # get current value
            i = i + 1     # move to next depth level
        
        # Fill all levels above index i with the found value x
        # → effectively extrapolates the first valid value upward
        prof[:i] = x
    
    # Return the modified array (already changed in place)
    return param

# %%
# def daily_average(times, lons, lats, data):
#     """Average profiles occurring on the same day (ordinal date)."""
#     day_index = np.floor(times).astype(int)
    
#     unique_days = np.unique(day_index)
#     avg_times  = unique_days
#     avg_lons   = np.array([lons[day_index == d].mean() for d in unique_days])
#     avg_lats   = np.array([lats[day_index == d].mean() for d in unique_days])
#     avg_data   = np.array([np.nanmean(data[day_index == d], axis=0) for d in unique_days])
#     avg_counts = np.array([np.sum(day_index == d) for d in unique_days])
    
#     return avg_times, avg_lons, avg_lats, avg_data, avg_counts

# %%
itp_path = '/data0/user/aprigent/ITP/'
list_file = glob.glob(itp_path + '*DM_final.nc')
list_file
# Out:
# ['/data0/user/aprigent/ITP/ITP_13_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_72_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_131_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_63_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_47_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_49_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_132_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_102_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_71_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_122_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_42_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_36_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_56_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_75_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_109_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_37_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_23_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_16_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_92_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_121_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_54_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_82_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_69_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_89_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_55_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_130_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_117_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_125_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_28_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_74_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_110_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_18_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_10_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_7_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_1_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_90_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_43_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_101_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_126_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_128_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_111_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_115_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_12_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_70_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_98_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_26_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_51_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_27_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_129_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_66_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_80_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_84_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_24_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_100_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_57_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_120_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_113_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_79_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_30_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_88_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_119_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_83_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_91_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_105_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_104_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_78_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_68_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_6_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_118_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_58_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_99_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_52_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_53_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_64_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_73_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_35_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_32_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_77_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_2_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_33_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_62_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_60_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_29_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_94_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_81_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_76_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_15_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_5_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_22_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_103_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_65_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_85_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_114_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_25_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_17_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_97_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_123_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_38_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_11_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_61_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_4_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_19_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_95_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_108_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_127_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_59_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_41_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_14_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_107_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_116_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_9_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_34_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_48_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_21_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_87_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_86_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_3_L3_DM_final.nc',
#  '/data0/user/aprigent/ITP/ITP_8_L3_DM_final.nc']

# %%
test = xr.open_dataset('/data0/user/aprigent/ITP/ITP_9_L3_DM_final.nc',decode_times=False)
test
# Out:
# <xarray.Dataset>
# Dimensions:              (N_PROF: 1480, N_LEVELS: 786)
# Dimensions without coordinates: N_PROF, N_LEVELS
# Data variables: (12/63)
#     REFERENCE_DATE_TIME  |S16 ...
#     DATA_TYPE            |S16 ...
#     PLATFORM_NUMBER      (N_PROF) |S8 ...
#     WMO_INST_TYPE        (N_PROF) |S4 ...
#     PI_NAME              (N_PROF) |S64 ...
#     DATA_CENTRE          (N_PROF) |S4 ...
#     ...                   ...
#     PRES_ADJUSTED        (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_CLMN   (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_CLSD   (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_ERME   (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_ERROR  (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_RESI   (N_PROF, N_LEVELS) float32 ...
# Attributes:
#     Conventions:       CF-1.4
#     title:             ITP DATA
#     institution:       LOPS/IUEM
#     project_name:      SNO-ARGO/ISAS
#     data_manager:      Nicolas Kolodziejczyk
#     software_version:  v2
#     references:        The Ice-Tethered Profiler data were collected and made...
#     history:           20260318T095739L : Creation

# %%
test.TEMP_ADJUSTED_ERROR.min()
# Out:
# <xarray.DataArray 'TEMP_ADJUSTED_ERROR' ()>
# array(0., dtype=float32)

# %% [markdown]
# # Start looping on ITP individual files

# %%
black_list = [itp_path+'ITP_132_L3_DM_final.nc',\
              itp_path+'ITP_66_L3_DM_final.nc',\
             itp_path+'ITP_55_L3_DM_final.nc',\
             itp_path+'ITP_71_L3_DM_final.nc',\
             itp_path+'ITP_8_L3_DM_final.nc']

data_out = '/data0/user/aprigent/ITP/'
for f in list_file:
    itp = xr.open_dataset(f,decode_times=False)
    juld_qc = itp.JULD_QC.data
    qc_time = juld_qc == b'1'
    # extract ITP number
    itp_id = int(os.path.basename(f).split('_')[1])
    print(itp_id)
    juld_ord = [dt.datetime(1950,1,1).toordinal() + t for t in itp.JULD.data[qc_time]]
    if len(juld_ord) == 0:
        print('No QC time')
        continue
        
    if juld_ord[-1]> dt.datetime(1999,12,31).toordinal():
        if f not in black_list:
            # print(f)
            pres = itp.PRES_ADJUSTED.data[qc_time]
            lat = itp.LATITUDE.data[qc_time]
            lon = itp.LONGITUDE.data[qc_time]
            psal= itp.PSAL_ADJUSTED.data[qc_time]
            temp=itp.TEMP_ADJUSTED.data[qc_time]
            psal_qc = itp.PSAL_ADJUSTED_QC.data[qc_time]
            temp_qc = itp.TEMP_ADJUSTED_QC.data[qc_time]
            pos_qc = itp.POSITION_QC.data[qc_time]
            pres_qc =itp.PRES_ADJUSTED_QC.data[qc_time] 
            data_mode = itp.DATA_MODE.data[qc_time]
            
            qc_press = pres_qc == b'1'
            pres[~qc_press] = np.nan
            dep = -gsw.z_from_p(pres.T,lat).T
            
            qc1_psal = psal_qc == b'1'
            qc1_temp = temp_qc == b'1'
            qc1_pos = pos_qc == b'1'
            qc_mode = (data_mode == b'D')


            
            qc_mode_2d_psal = np.broadcast_to(qc_mode[:, None], psal.shape)
            qc_mode_2d_temp = np.broadcast_to(qc_mode[:, None], temp.shape)
            qc_pos_2d_psal = np.broadcast_to(qc1_pos[:, None], psal.shape)
            qc_pos_2d_temp = np.broadcast_to(qc1_pos[:, None], temp.shape)

            final_mask_temp = ~(qc_pos_2d_temp & qc1_temp & qc_press & qc_mode_2d_temp)
            final_mask_psal = ~(qc_pos_2d_psal & qc1_psal & qc_press & qc_mode_2d_psal)


            psal[final_mask_psal] = np.nan
            temp[final_mask_temp] = np.nan  
            
            
            n_levels_temp = np.ones((dep.shape[0]))*np.sum(np.isfinite(dep[:,:]),axis=1)
            n_levels_psal  = np.ones((dep.shape[0]))*np.sum(np.isfinite(dep[:,:]),axis=1)

            sum_temp = np.nansum(temp,axis=1)
            sum_psal  = np.nansum(psal,axis=1)
            sum_dep = np.nansum(dep,axis=1)
            
    
            PSAL,ipsal = interp_prof(dep,psal,zi)
            TEMP,itemp = interp_prof(dep,temp,zi)
            
            
            
            
            if len(ipsal) != len(itemp):
                print('psal/temp dimension missmatch')
            TIMEs = np.array(juld_ord)[ipsal]
            LONs = lon[ipsal]
            LATs = lat[ipsal]
            sum_PSAL = sum_psal[ipsal]
            n_levels_PSAL = n_levels_psal[ipsal]
            sum_dep_PSAL = sum_dep[ipsal]
            
            
            TIMEt = np.array(juld_ord)[itemp]
            LONt = lon[itemp]
            LATt = lat[itemp]
            sum_TEMP = sum_temp[itemp]
            n_levels_TEMP = n_levels_temp[itemp]
            sum_dep_TEMP = sum_dep[itemp]
            
            TEMP[TEMP<-2] = np.nan
            TEMP[TEMP>30] = np.nan
            PSAL[PSAL<0] = np.nan
            PSAL[PSAL>40] = np.nan
            
            itp_id_PSAL = np.full(len(TIMEs), itp_id)
            itp_id_TEMP = np.full(len(TIMEt), itp_id)
            
            
            print('TEMP max = ',np.nanmax(TEMP))
            print('TEMP min = ',np.nanmin(TEMP))
            print('PSAL max = ',np.nanmax(PSAL))
            print('PSAL min = ',np.nanmin(PSAL))
            
            
            # --- Daily averaging before saving ---
            # TIMEs_int, LONs_int, LATs_int, PSAL_int, COUNTs = daily_average(TIMEs, LONs, LATs, PSAL)
            # TIMEt_int, LONt_int, LATt_int, TEMP_int, COUNTt = daily_average(TIMEt, LONt, LATt, TEMP)
            print(f[25:])
        
            # save file PSAL
            ds = xr.Dataset({'latitude': (['prof'], LATs),
                             'longitude': (['prof'], LONs),
                             'time': (['prof'], TIMEs),
                             'salinity': (['prof','levels'], PSAL),
                             'sum_salinity': (['prof'], sum_PSAL),
                             'sum_levels': (['prof'], sum_dep_PSAL),
                             'nb_levels': (['prof'], n_levels_PSAL),
                             'platform_id': (['prof'], itp_id_PSAL),
                             'depth': (['levels'], zi)},
                            coords={'prof': (['prof'], np.arange(0,len(TIMEs))), 'levels':(['levels'], zi)})
            
            # global attributes
            ds.attrs['Comments'] = 'ITP salinity profiles (qc=1) interpolated on ISAS vertical levels using a Akima 1D interpolator scheme (scipy)'
            ds.attrs['Original file'] = f[25:]
            ds.attrs['title'] = 'ITP salinity profiles on ISAS vertical grid'
            ds.attrs['source'] = 'ITP'
            ds.attrs['history'] = 'Created with xarray'
            ds['platform_id'].attrs = {'long_name': 'Ice-Tethered Profiler ID'}
            
            # variable attributes
            ds['latitude'].attrs = {'long_name':'Latitude','units':'degrees_north','standard_name':'latitude'}
            ds['longitude'].attrs = {'long_name':'Longitude','units':'degrees_east','standard_name':'longitude'}
            ds['time'].attrs = {'long_name':'Time',
                                "units": "days since 0001-01-01 (Python datetime system)"}
            ds['salinity'].attrs = {'long_name':'Salinity (S78 - PSS)',
                                    'units':'1e-3',   # or 'psu'
                                    'standard_name':'sea_water_practical_salinity'}
            ds['depth'].attrs = {'long_name':'Depth','units':'m','positive':'down','standard_name':'depth'}
            


            ds.to_netcdf(data_out + f[25:-3] + '_ISAS_PSAL.nc')   
            
            # save file TEMP
            ds = xr.Dataset({'latitude': (['prof'], LATt),\
                             'longitude': (['prof'], LONt),\
                             'time': (['prof'], TIMEt),\
                             'temperature': (['prof','levels'], TEMP),\
                             'sum_temperature': (['prof'], sum_TEMP),
                             'sum_levels': (['prof'], sum_dep_TEMP),
                             'nb_levels': (['prof'], n_levels_TEMP),
                             'platform_id': (['prof'], itp_id_TEMP),
                             'depth': (['levels'], zi)},\
                            coords={'prof': (['prof'], np.arange(0,len(TIMEt))), 'levels':(['levels'], zi)})

            # global attributes
            ds.attrs['Comments'] = 'ITP temperature profiles (qc=1) interpolated on ISAS vertical using a Akima 1D interpolator scheme (scipy)'
            ds.attrs['Original file'] = f[25:]
            ds.attrs['title'] = 'ITP temperature profiles on ISAS vertical grid'
            ds.attrs['source'] = 'ITP'
            ds.attrs['history'] = 'Created with xarray'
            ds['platform_id'].attrs = {'long_name': 'Ice-Tethered Profiler ID'}
            
            # variable attributes
            ds['latitude'].attrs = {'long_name':'Latitude','units':'degrees_north','standard_name':'latitude'}
            ds['longitude'].attrs = {'long_name':'Longitude','units':'degrees_east','standard_name':'longitude'}
            ds['time'].attrs = {'long_name':'Time',
                                "units": "days since 0001-01-01 (Python datetime system)"}
            ds['temperature'].attrs = {'long_name':'Temperature (T90)',
                                       'units':'degree_Celsius',
                                       'standard_name':'sea_water_temperature'}
            ds['depth'].attrs = {'long_name':'Depth','units':'m','positive':'down','standard_name':'depth'}

  
            ds.to_netcdf(data_out + f[25:-3] + '_ISAS_TEMP.nc')
# Out:
# 13
# TEMP max =  1.1082187675785315
# TEMP min =  -1.6574256814272488
# PSAL max =  34.886050884330395
# PSAL min =  23.62588561068064
# ITP_13_L3_DM_final.nc
# 72
# TEMP max =  1.58523357973919
# TEMP min =  -1.8305412569724675
# PSAL max =  34.9237582942463
# PSAL min =  30.60773677299164
# ITP_72_L3_DM_final.nc
# 131
# TEMP max =  0.9662488443604668
# TEMP min =  -1.5548451906967031
# PSAL max =  34.8752051741939
# PSAL min =  26.70334684197121
# ITP_131_L3_DM_final.nc
# 63
# psal/temp dimension missmatch
# TEMP max =  0.6329725230324839
# TEMP min =  -1.6861179960181807
# PSAL max =  34.8916120344254
# PSAL min =  29.05322545167336
# ITP_63_L3_DM_final.nc
# 47
# psal/temp dimension missmatch
# TEMP max =  1.859091566946638
# TEMP min =  -1.8142596008991692
# PSAL max =  34.89949171080213
# PSAL min =  30.82176517203518
# ITP_47_L3_DM_final.nc
# 49
# TEMP max =  1.333848933575242
# TEMP min =  -1.7591320167040165
# PSAL max =  34.89015964600733
# PSAL min =  28.16043721598719
# ITP_49_L3_DM_final.nc
# 132
# 102
# TEMP max =  1.6188649040074683
# TEMP min =  -1.835093582059416
# PSAL max =  34.90342742539935
# PSAL min =  31.00457279364594
# ITP_102_L3_DM_final.nc
# 71
# 122
# psal/temp dimension missmatch
# TEMP max =  0.9245728492450948
# TEMP min =  -1.658728121731912
# PSAL max =  34.8737330832974
# PSAL min =  26.102692637824894
# ITP_122_L3_DM_final.nc
# 42
# TEMP max =  2.652286159904981
# TEMP min =  -1.7455248494370732
# PSAL max =  34.874940343641526
# PSAL min =  25.411361130722298
# ITP_42_L3_DM_final.nc
# 36
# psal/temp dimension missmatch
# TEMP max =  2.04174211804972
# TEMP min =  -1.8595473938279843
# PSAL max =  34.9157138579789
# PSAL min =  29.49942988735161
# ITP_36_L3_DM_final.nc
# 56
# psal/temp dimension missmatch
# TEMP max =  5.194559936581419
# TEMP min =  -1.8384742885056171
# PSAL max =  35.180724084558776
# PSAL min =  31.899720480289254
# ITP_56_L3_DM_final.nc
# 75
# psal/temp dimension missmatch
# TEMP max =  2.5761116090631093
# TEMP min =  -1.8718764391209854
# PSAL max =  34.97730785577747
# PSAL min =  31.57266629799046
# ITP_75_L3_DM_final.nc
# 109
# psal/temp dimension missmatch
# TEMP max =  0.8382141184566547
# TEMP min =  -1.535562973504191
# PSAL max =  34.867770636161815
# PSAL min =  27.346483177169915
# ITP_109_L3_DM_final.nc
# 37
# psal/temp dimension missmatch
# TEMP max =  4.042673952872678
# TEMP min =  -1.857241273305799
# PSAL max =  35.01859621312407
# PSAL min =  32.57867949084131
# ITP_37_L3_DM_final.nc
# 23
# TEMP max =  0.8721605356925884
# TEMP min =  -1.6865336850480341
# PSAL max =  34.89083373881621
# PSAL min =  26.737645249516614
# ITP_23_L3_DM_final.nc
# 16
# psal/temp dimension missmatch
# TEMP max =  0.9192945353208084
# TEMP min =  -1.7585780539033855
# PSAL max =  34.88315261668439
# PSAL min =  28.780344795518047
# ITP_16_L3_DM_final.nc
# 92
# TEMP max =  1.0147038832096953
# TEMP min =  -1.7465913674366975
# PSAL max =  34.87426086061294
# PSAL min =  27.847375524349065
# ITP_92_L3_DM_final.nc
# 121
# psal/temp dimension missmatch
# TEMP max =  3.1278115452759834
# TEMP min =  -1.6713621135957994
# PSAL max =  34.86498111926515
# PSAL min =  25.844935076853147
# ITP_121_L3_DM_final.nc
# 54
# TEMP max =  0.8332390694576394
# TEMP min =  -1.5614993787567168
# PSAL max =  34.865503144409175
# PSAL min =  24.680846860401346
# ITP_54_L3_DM_final.nc
# 82
# psal/temp dimension missmatch
# TEMP max =  2.0262389456093417
# TEMP min =  -1.6926006477096733
# PSAL max =  34.87548793509993
# PSAL min =  26.455705463576592
# ITP_82_L3_DM_final.nc
# 69
# TEMP max =  0.8443345107918376
# TEMP min =  -1.7319158840834579
# PSAL max =  34.867606547808904
# PSAL min =  26.098495787418475
# ITP_69_L3_DM_final.nc
# 89
# TEMP max =  0.8744797954071095
# TEMP min =  -1.7343707299713262
# PSAL max =  34.86658740353916
# PSAL min =  27.004924756451498
# ITP_89_L3_DM_final.nc
# 55
# 130
# psal/temp dimension missmatch
# TEMP max =  1.01546536016805
# TEMP min =  -1.7330937922762728
# PSAL max =  34.863890589900144
# PSAL min =  26.147952013024433
# ITP_130_L3_DM_final.nc
# 117
# TEMP max =  0.8311439245497988
# TEMP min =  -1.579791019396348
# PSAL max =  34.870376770439705
# PSAL min =  27.28260880610261
# ITP_117_L3_DM_final.nc
# 125
# psal/temp dimension missmatch
# TEMP max =  1.1588894919771957
# TEMP min =  -1.6451403150523256
# PSAL max =  34.85942551021912
# PSAL min =  27.81834689636315
# ITP_125_L3_DM_final.nc
# 28
# TEMP max =  1.0292846523921089
# TEMP min =  -1.6665279151458416
# PSAL max =  34.879182288006874
# PSAL min =  29.17264122042929
# ITP_28_L3_DM_final.nc
# 74
# psal/temp dimension missmatch
# TEMP max =  2.718211456609681
# TEMP min =  -1.8693832171885403
# PSAL max =  34.96932700351755
# PSAL min =  30.329029325910767
# ITP_74_L3_DM_final.nc
# 110
# psal/temp dimension missmatch
# TEMP max =  1.6086858696969322
# TEMP min =  -1.7505379118352578
# PSAL max =  34.86585918219503
# PSAL min =  25.877833045661816
# ITP_110_L3_DM_final.nc
# 18
# psal/temp dimension missmatch
# TEMP max =  2.1806368297814567
# TEMP min =  -1.6679835580973263
# PSAL max =  34.87508921405266
# PSAL min =  23.210450491707494
# ITP_18_L3_DM_final.nc
# 10
# TEMP max =  0.5040393823084843
# TEMP min =  -1.6453894830453955
# PSAL max =  34.890121801338644
# PSAL min =  28.924998341478567
# ITP_10_L3_DM_final.nc
# 7
# TEMP max =  3.1861382090878094
# TEMP min =  -1.842413321004568
# PSAL max =  35.43160762803752
# PSAL min =  31.907973205913432
# ITP_7_L3_DM_final.nc
# 1
# TEMP max =  1.2609969621425177
# TEMP min =  -1.6590569997164928
# PSAL max =  34.883026357324056
# PSAL min =  25.882185077480475
# ITP_1_L3_DM_final.nc
# 90
# psal/temp dimension missmatch
# TEMP max =  1.9802338222831504
# TEMP min =  -1.8643305072614038
# PSAL max =  34.90789841846976
# PSAL min =  30.782156815008882
# ITP_90_L3_DM_final.nc
# 43
# TEMP max =  0.840053881303796
# TEMP min =  -1.7371358668220591
# PSAL max =  34.86461252836414
# PSAL min =  25.508936402244505
# ITP_43_L3_DM_final.nc
# 101
# psal/temp dimension missmatch
# TEMP max =  0.8215592984702429
# TEMP min =  -1.6362667447889576
# PSAL max =  34.871735139555085
# PSAL min =  28.12683781101707
# ITP_101_L3_DM_final.nc
# 126
# psal/temp dimension missmatch
# TEMP max =  0.9531679465008187
# TEMP min =  -1.6928982663277188
# PSAL max =  34.87783831019055
# PSAL min =  27.139832423721682
# ITP_126_L3_DM_final.nc
# 128
# TEMP max =  1.1834968364892193
# TEMP min =  -1.7418210443830335
# PSAL max =  34.868461460071465
# PSAL min =  27.807011676203302
# ITP_128_L3_DM_final.nc
# 111
# psal/temp dimension missmatch
# TEMP max =  2.7793069244294006
# TEMP min =  -1.8786969148330266
# PSAL max =  34.94441025520879
# PSAL min =  31.56262233905439
# ITP_111_L3_DM_final.nc
# 115
# TEMP max =  1.0151376979762894
# TEMP min =  -1.670595357042456
# PSAL max =  34.86247495150123
# PSAL min =  26.769919282272877
# ITP_115_L3_DM_final.nc
# 12
# TEMP max =  1.5010237622826361
# TEMP min =  -1.7596513343725275
# PSAL max =  34.89637665140147
# PSAL min =  29.862078660595586
# ITP_12_L3_DM_final.nc
# 70
# TEMP max =  0.9708474152116252
# TEMP min =  -1.765590009648879
# PSAL max =  34.86649996642561
# PSAL min =  26.807829501809653
# ITP_70_L3_DM_final.nc
# 98
# psal/temp dimension missmatch
# TEMP max =  0.7704233252607815
# TEMP min =  -1.703738873430945
# PSAL max =  34.86638500956478
# PSAL min =  28.502810391172986
# ITP_98_L3_DM_final.nc
# 26
# psal/temp dimension missmatch
# TEMP max =  1.5341424066824763
# TEMP min =  -1.8111974475538792
# PSAL max =  34.8931289311603
# PSAL min =  29.768189558328288
# ITP_26_L3_DM_final.nc
# 51
# TEMP max =  2.4932322232572126
# TEMP min =  -1.8111980390402111
# PSAL max =  34.98643189460023
# PSAL min =  31.57655419742712
# ITP_51_L3_DM_final.nc
# 27
# psal/temp dimension missmatch
# TEMP max =  1.264956749050744
# TEMP min =  -1.7893946716768006
# PSAL max =  34.881017882262626
# PSAL min =  28.53834651642158
# ITP_27_L3_DM_final.nc
# 129
# psal/temp dimension missmatch
# TEMP max =  2.1025311259167814
# TEMP min =  -1.866092597970889
# PSAL max =  34.937002958240484
# PSAL min =  30.66279819544588
# ITP_129_L3_DM_final.nc
# 66
# 80
# TEMP max =  0.9008710557516797
# TEMP min =  -1.7335462695400192
# PSAL max =  34.870810437108254
# PSAL min =  26.774229476391003
# ITP_80_L3_DM_final.nc
# 84
# psal/temp dimension missmatch
# TEMP max =  0.7835667431897995
# TEMP min =  -1.6330701654462723
# PSAL max =  34.86500873526034
# PSAL min =  26.22267489734727
# ITP_84_L3_DM_final.nc
# 24
# psal/temp dimension missmatch
# TEMP max =  2.3181793533192816
# TEMP min =  -1.8482875136741732
# PSAL max =  34.951495226184754
# PSAL min =  31.647283420530307
# ITP_24_L3_DM_final.nc
# 100
# psal/temp dimension missmatch
# TEMP max =  0.89422969560036
# TEMP min =  -1.7831665935090848
# PSAL max =  34.88023711242752
# PSAL min =  27.745642040785103
# ITP_100_L3_DM_final.nc
# 57
# psal/temp dimension missmatch
# TEMP max =  2.7419682352269303
# TEMP min =  -1.8615790135975308
# PSAL max =  34.90746837920688
# PSAL min =  28.480260536455383
# ITP_57_L3_DM_final.nc
# 120
# psal/temp dimension missmatch
# TEMP max =  3.44491738429553
# TEMP min =  -1.7642216153172876
# PSAL max =  34.87379754151471
# PSAL min =  24.837747914542096
# ITP_120_L3_DM_final.nc
# 113
# psal/temp dimension missmatch
# TEMP max =  1.8917535721488807
# TEMP min =  -1.7641874588394175
# PSAL max =  34.86733124147843
# PSAL min =  23.64171681949216
# ITP_113_L3_DM_final.nc
# 79
# psal/temp dimension missmatch
# TEMP max =  0.7706150081952807
# TEMP min =  -1.7221063557248573
# PSAL max =  34.86759487025163
# PSAL min =  26.090343317174227
# ITP_79_L3_DM_final.nc
# 30
# TEMP max =  0.8864617692430147
# TEMP min =  -1.5529775673283452
# PSAL max =  34.86232908349078
# PSAL min =  25.02052526807031
# ITP_30_L3_DM_final.nc
# 88
# TEMP max =  0.8377684698781737
# TEMP min =  -1.5403317817794662
# PSAL max =  34.86525932088026
# PSAL min =  27.322570581467176
# ITP_88_L3_DM_final.nc
# 119
# TEMP max =  1.5814030617390913
# TEMP min =  -1.7216968920972586
# PSAL max =  34.86573031119014
# PSAL min =  26.60968093055657
# ITP_119_L3_DM_final.nc
# 83
# psal/temp dimension missmatch
# TEMP max =  1.9081680817226867
# TEMP min =  -1.8380435064569653
# PSAL max =  34.941381505509
# PSAL min =  31.71591279716339
# ITP_83_L3_DM_final.nc
# 91
# psal/temp dimension missmatch
# TEMP max =  1.5061201362395165
# TEMP min =  -1.8730326809010291
# PSAL max =  34.90434013419953
# PSAL min =  30.63170788877568
# ITP_91_L3_DM_final.nc
# 105
# psal/temp dimension missmatch
# TEMP max =  0.8622864970175033
# TEMP min =  -1.6783930534713944
# PSAL max =  34.87173367337472
# PSAL min =  29.17739068371387
# ITP_105_L3_DM_final.nc
# 104
# TEMP max =  0.8019388334918635
# TEMP min =  -1.7656551267420566
# PSAL max =  34.87138615029715
# PSAL min =  29.696921137721592
# ITP_104_L3_DM_final.nc
# 78
# TEMP max =  0.7585074737872389
# TEMP min =  -1.5895650519712614
# PSAL max =  34.86674891814701
# PSAL min =  26.952682838724368
# ITP_78_L3_DM_final.nc
# 68
# psal/temp dimension missmatch
# TEMP max =  0.8487519823031169
# TEMP min =  -1.7141149284525254
# PSAL max =  34.864489945556635
# PSAL min =  26.472423278371785
# ITP_68_L3_DM_final.nc
# 6
# TEMP max =  0.9647592781597419
# TEMP min =  -1.6315870525371987
# PSAL max =  35.15244250683783
# PSAL min =  22.513114537920888
# ITP_6_L3_DM_final.nc
# 118
# TEMP max =  0.859802149264367
# TEMP min =  -1.5410609752796465
# PSAL max =  34.86891714279108
# PSAL min =  26.861848654059077
# ITP_118_L3_DM_final.nc
# 58
# psal/temp dimension missmatch
# TEMP max =  2.7281588677420534
# TEMP min =  -1.8612047041526083
# PSAL max =  35.01211134211114
# PSAL min =  30.416798071104076
# ITP_58_L3_DM_final.nc
# 99
# psal/temp dimension missmatch
# TEMP max =  0.8341106320602585
# TEMP min =  -1.549070294268071
# PSAL max =  34.86328889981177
# PSAL min =  27.58924809642253
# ITP_99_L3_DM_final.nc
# 52
# psal/temp dimension missmatch
# TEMP max =  0.8331296612785268
# TEMP min =  -1.710970520544932
# PSAL max =  34.871143001526114
# PSAL min =  25.77050995169462
# ITP_52_L3_DM_final.nc
# 53
# psal/temp dimension missmatch
# TEMP max =  0.8595029313591896
# TEMP min =  -1.7608102212511694
# PSAL max =  34.869562799578866
# PSAL min =  24.642372040689633
# ITP_53_L3_DM_final.nc
# 64
# TEMP max =  2.02963707719168
# TEMP min =  -1.7669789682452586
# PSAL max =  34.87107544607096
# PSAL min =  25.754934138665714
# ITP_64_L3_DM_final.nc
# 73
# psal/temp dimension missmatch
# TEMP max =  2.3241414067418718
# TEMP min =  -1.8156948674180808
# PSAL max =  34.943327103469734
# PSAL min =  32.10802293277981
# ITP_73_L3_DM_final.nc
# 35
# TEMP max =  0.8422280821135864
# TEMP min =  -1.5806312911793639
# PSAL max =  34.86780317215632
# PSAL min =  25.81810218059602
# ITP_35_L3_DM_final.nc
# 32
# TEMP max =  0.9251013131628923
# TEMP min =  -1.6020619494129278
# PSAL max =  34.876051221939335
# PSAL min =  27.41333720598772
# ITP_32_L3_DM_final.nc
# 77
# TEMP max =  0.8594287766449383
# TEMP min =  -1.6677998408132304
# PSAL max =  34.86800045825362
# PSAL min =  26.09514238182412
# ITP_77_L3_DM_final.nc
# 2
# TEMP max =  0.9578300639357149
# TEMP min =  -1.5953415716552437
# PSAL max =  34.881035412213166
# PSAL min =  28.50621425194494
# ITP_2_L3_DM_final.nc
# 33
# psal/temp dimension missmatch
# TEMP max =  6.508035572515704
# TEMP min =  -1.7445879762257417
# PSAL max =  34.87117669369104
# PSAL min =  24.89212359524341
# ITP_33_L3_DM_final.nc
# 62
# psal/temp dimension missmatch
# TEMP max =  0.8528023885874847
# TEMP min =  -1.7793528660537685
# PSAL max =  34.87238295886583
# PSAL min =  25.725040942923314
# ITP_62_L3_DM_final.nc
# 60
# TEMP max =  1.402291255013976
# TEMP min =  -1.7864727821807458
# PSAL max =  34.88899940574696
# PSAL min =  29.796767648650835
# ITP_60_L3_DM_final.nc
# 29
# psal/temp dimension missmatch
# TEMP max =  1.412846955260174
# TEMP min =  -1.8346314245494404
# PSAL max =  34.90637823976231
# PSAL min =  28.481321078683013
# ITP_29_L3_DM_final.nc
# 94
# psal/temp dimension missmatch
# TEMP max =  2.644663343273521
# TEMP min =  -1.8795422085255686
# PSAL max =  34.95074810386138
# PSAL min =  31.54608030709083
# ITP_94_L3_DM_final.nc
# 81
# TEMP max =  0.9213008835967803
# TEMP min =  -1.6201402808426963
# PSAL max =  34.88041311184134
# PSAL min =  27.193506816278582
# ITP_81_L3_DM_final.nc
# 76
# psal/temp dimension missmatch
# TEMP max =  4.743155930418043
# TEMP min =  -1.8583952063328737
# PSAL max =  35.13629921369847
# PSAL min =  30.379470177127075
# ITP_76_L3_DM_final.nc
# 15
# psal/temp dimension missmatch
# TEMP max =  1.127224714434461
# TEMP min =  -1.7506527904283875
# PSAL max =  34.9091426307547
# PSAL min =  28.136096829742694
# ITP_15_L3_DM_final.nc
# 5
# TEMP max =  1.2942490257926023
# TEMP min =  -1.624566678264585
# PSAL max =  34.8667233611034
# PSAL min =  25.28861698916458
# ITP_5_L3_DM_final.nc
# 22
# TEMP max =  0.8168431520076795
# TEMP min =  -1.4775713455035087
# PSAL max =  34.87893300561334
# PSAL min =  26.3614827485702
# ITP_22_L3_DM_final.nc
# 103
# psal/temp dimension missmatch
# TEMP max =  0.8035531028299595
# TEMP min =  -1.742261162262018
# PSAL max =  34.86409138723791
# PSAL min =  28.60569857351362
# ITP_103_L3_DM_final.nc
# 65
# psal/temp dimension missmatch
# TEMP max =  1.0704906523039805
# TEMP min =  -1.701002923459171
# PSAL max =  34.876669982113754
# PSAL min =  27.351531012023877
# ITP_65_L3_DM_final.nc
# 85
# TEMP max =  0.8955311013579311
# TEMP min =  -1.6261952244465747
# PSAL max =  34.87107455440575
# PSAL min =  25.64868962575257
# ITP_85_L3_DM_final.nc
# 114
# psal/temp dimension missmatch
# TEMP max =  2.48867011690154
# TEMP min =  -1.759080953216264
# PSAL max =  34.94959325229386
# PSAL min =  25.670280751232454
# ITP_114_L3_DM_final.nc
# 25
# TEMP max =  0.8829156508244129
# TEMP min =  -1.7214434270336423
# PSAL max =  34.89233925844638
# PSAL min =  29.155499474044245
# ITP_25_L3_DM_final.nc
# 17
# TEMP max =  1.2942610489882755
# TEMP min =  -1.8353627759185747
# PSAL max =  34.89344815794993
# PSAL min =  31.631328998195553
# ITP_17_L3_DM_final.nc
# 97
# psal/temp dimension missmatch
# TEMP max =  3.4913390063353287
# TEMP min =  -1.674997819089892
# PSAL max =  34.86998221297822
# PSAL min =  25.539270242513005
# ITP_97_L3_DM_final.nc
# 123
# psal/temp dimension missmatch
# TEMP max =  3.434981481876714
# TEMP min =  -1.8167724560370115
# PSAL max =  34.862866437321564
# PSAL min =  25.331796009953166
# ITP_123_L3_DM_final.nc
# 38
# psal/temp dimension missmatch
# TEMP max =  4.3287653205910095
# TEMP min =  -1.8478127074777837
# PSAL max =  35.1258632316355
# PSAL min =  30.32963343312928
# ITP_38_L3_DM_final.nc
# 11
# TEMP max =  3.2636968115531695
# TEMP min =  -1.684748102044721
# PSAL max =  34.888817784143775
# PSAL min =  22.88904515301319
# ITP_11_L3_DM_final.nc
# 61
# psal/temp dimension missmatch
# TEMP max =  1.5543371947691484
# TEMP min =  -1.8526139027707422
# PSAL max =  34.929018202347606
# PSAL min =  29.499861874169074
# ITP_61_L3_DM_final.nc
# 4
# TEMP max =  1.374456126392604
# TEMP min =  -1.7546659660722923
# PSAL max =  34.931994444333945
# PSAL min =  25.991542940954055
# ITP_4_L3_DM_final.nc
# 19
# TEMP max =  2.0929020304020356
# TEMP min =  -1.860237251046257
# PSAL max =  34.95683914525942
# PSAL min =  32.23990877625457
# ITP_19_L3_DM_final.nc
# 95
# psal/temp dimension missmatch
# TEMP max =  3.2401418549106653
# TEMP min =  -1.8483864348894967
# PSAL max =  35.015498103931535
# PSAL min =  31.15848210374515
# ITP_95_L3_DM_final.nc
# 108
# psal/temp dimension missmatch
# TEMP max =  0.9676360059317154
# TEMP min =  -1.7442527984118301
# PSAL max =  34.87334325401795
# PSAL min =  27.552736887018984
# ITP_108_L3_DM_final.nc
# 127
# psal/temp dimension missmatch
# TEMP max =  0.95721604393232
# TEMP min =  -1.7212386042598493
# PSAL max =  34.87513332867404
# PSAL min =  26.95697214513854
# ITP_127_L3_DM_final.nc
# 59
# psal/temp dimension missmatch
# TEMP max =  1.202188909836141
# TEMP min =  -1.7177300677176437
# PSAL max =  34.87070768089034
# PSAL min =  30.423516750126133
# ITP_59_L3_DM_final.nc
# 41
# psal/temp dimension missmatch
# TEMP max =  1.3961871319482078
# TEMP min =  -1.59541514182489
# PSAL max =  34.88020185938078
# PSAL min =  25.211434617969164
# ITP_41_L3_DM_final.nc
# 14
# TEMP max =  1.439787932354589
# TEMP min =  -1.8310692861545166
# PSAL max =  34.890852078599266
# PSAL min =  31.154439354213714
# ITP_14_L3_DM_final.nc
# 107
# psal/temp dimension missmatch
# TEMP max =  2.0393242889623666
# TEMP min =  -1.547775061813086
# PSAL max =  34.86553396173464
# PSAL min =  27.088396110757643
# ITP_107_L3_DM_final.nc
# 116
# psal/temp dimension missmatch
# TEMP max =  1.4000148522291158
# TEMP min =  -1.831091902178501
# PSAL max =  34.900540903320284
# PSAL min =  30.947137337880115
# ITP_116_L3_DM_final.nc
# 9
# TEMP max =  0.917351842211936
# TEMP min =  -1.7335794299556408
# PSAL max =  34.895920560691536
# PSAL min =  28.784568766789903
# ITP_9_L3_DM_final.nc
# 34
# psal/temp dimension missmatch
# TEMP max =  0.8542751609684378
# TEMP min =  -1.7093793001388327
# PSAL max =  34.86823692517653
# PSAL min =  25.120512255705968
# ITP_34_L3_DM_final.nc
# 48
# psal/temp dimension missmatch
# TEMP max =  1.1879027417236212
# TEMP min =  -1.8153940457818976
# PSAL max =  34.88685038572743
# PSAL min =  27.686844438515987
# ITP_48_L3_DM_final.nc
# 21
# psal/temp dimension missmatch
# TEMP max =  0.9650858237805848
# TEMP min =  -1.8033469022001625
# PSAL max =  34.86969450129824
# PSAL min =  27.680086557932913
# ITP_21_L3_DM_final.nc
# 87
# psal/temp dimension missmatch
# TEMP max =  0.90315030637775
# TEMP min =  -1.774194728782344
# PSAL max =  34.87643323096542
# PSAL min =  27.349785791622352
# ITP_87_L3_DM_final.nc
# 86
# psal/temp dimension missmatch
# TEMP max =  1.7272627156613323
# TEMP min =  -1.7169352237705282
# PSAL max =  34.86729129304869
# PSAL min =  25.359728377269846
# ITP_86_L3_DM_final.nc
# 3
# TEMP max =  0.9513017863404747
# TEMP min =  -1.6363182772342242
# PSAL max =  34.87401549936689
# PSAL min =  24.616558505671982
# ITP_3_L3_DM_final.nc
# 8

# %%
itp_path = '/data0/user/aprigent/ITP/'
itp_list_psal = glob.glob(itp_path + '*ISAS_PSAL.nc')
itp_list_temp = glob.glob(itp_path + '*ISAS_TEMP.nc')
ds_itp_psal_new = Atools.create_merged_dataset_psal_itp(itp_list_psal,'ITP','psal')
ds_itp_temp_new = Atools.create_merged_dataset_temp_itp(itp_list_temp,'ITP','temp')

# %%
import cmocean
f,ax = plt.subplots(2,1,figsize=[10,10])
ax=ax.ravel()

ax[0].pcolor(ds_itp_psal_new.salinity.T,cmap=cmocean.cm.haline,vmin=31,vmax=35)
ax[0].invert_yaxis()
ax[1].pcolor(ds_itp_temp_new.temperature.T,cmap=cmocean.cm.thermal,vmin=-2,vmax=2)
ax[1].invert_yaxis()

# %%
f,ax = plt.subplots(1,2,figsize=[10,10],subplot_kw={'projection': ccrs.NorthPolarStereo()})
ax=ax.ravel()
ftz=15


plt.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.3
                    ,
                    wspace=0.3)


Atools.plot_arctic_ax_map_new(ax[0])
ax[0].scatter(ds_itp_psal_new.longitude,
           ds_itp_psal_new.latitude,
           marker='.',transform=ccrs.PlateCarree(),s=2,color='blue',label='CT',alpha=0.5)

Atools.plot_arctic_ax_map_new(ax[1])


ax[1].scatter(ds_itp_temp_new.longitude,
           ds_itp_temp_new.latitude,
           marker='.',transform=ccrs.PlateCarree(),s=2,color='red',label='CT',alpha=0.5)
